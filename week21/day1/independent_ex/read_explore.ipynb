# %%
import pandas as pd
df = pd.read_csv("ecommerce_fulfillment_dirty.csv")

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50250 entries, 0 to 50249
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          50250 non-null  str
#  1   Customer_Region   50250 non-null  str
#  2   Product_Category  50250 non-null  str
#  3   Order_Date        50250 non-null  str
#  4   Ship_Date         50250 non-null  str
#  5   Delivery_Date     49950 non-null  str
#  6   Shipping_Mode     50250 non-null  str
#  7   Shipping_Cost     50000 non-null  str
#  8   Delivery_Status   50250 non-null  str
#  9   Delivery_Days     50250 non-null  int64
# dtypes: int64(1), str(9)
# memory usage: 3.8 MB
# None

# %%
print(df.dtypes)
print(df.describe)
# Out:
# Order_ID              str
# Customer_Region       str
# Product_Category      str
# Order_Date            str
# Ship_Date             str
# Delivery_Date         str
# Shipping_Mode         str
# Shipping_Cost         str
# Delivery_Status       str
# Delivery_Days       int64
# dtype: object
# <bound method NDFrame.describe of       Order_ID Customer_Region Product_Category  Order_Date   Ship_Date  \
# 0      OR10000            West             Home   5/12/2024   5/16/2024
# 1      OR10001         Central             Home   4/19/2025   4/24/2025
# 2      OR10002            East             Home    7/2/2025    7/4/2025
# 3      OR10003         Central          Grocery   10/4/2025   10/8/2025
# 4      OR10004         Central           Sports  10/31/2023   11/2/2023
# ...        ...             ...              ...         ...         ...
# 50245  OR22430           North          Fashion   9/30/2025   10/1/2025
# 50246  OR20053           North           Sports   7/18/2023   7/22/2023
# 50247  OR20114            East             Home   7/14/2024   7/18/2024
# 50248  OR24989         Central      Electronics   5/23/2022   5/26/2022
# 50249  OR53191           North      Electronics  11/18/2023  11/19/2023
#
#       Delivery_Date Shipping_Mode Shipping_Cost Delivery_Status  Delivery_Days
# 0         5/26/2024      Standard         122.0       Delivered             10
# 1         4/26/2025      Standard         143.0       Delivered              2
# 2         7/11/2025      Standard         107.0         Delayed              7
# 3        10/16/2025      Standard         145.0         Delayed              8
# 4         11/7/2023      Standard         121.0       Delivered              5
# ...             ...           ...           ...             ...            ...
# 50245     10/4/2025      Standard         119.0       Delivered              3
# 50246     7/24/2023      Standard          62.0       Delivered              2
# 50247     7/22/2024       Express         204.0       Delivered              4
# 50248      6/1/2022       Express         110.0       Delivered              6
# 50249    11/23/2023      Standard         113.0       Delivered              4
#
# [50250 rows x 10 columns]>

# %%
print(df.isna().sum())
# Out:
# Order_ID              0
# Customer_Region       0
# Product_Category      0
# Order_Date            0
# Ship_Date             0
# Delivery_Date       300
# Shipping_Mode         0
# Shipping_Cost       250
# Delivery_Status       0
# Delivery_Days         0
# dtype: int64

# %%
print(df.isna().sum() / len(df) * 100)
# Out:
# Order_ID            0.000000
# Customer_Region     0.000000
# Product_Category    0.000000
# Order_Date          0.000000
# Ship_Date           0.000000
# Delivery_Date       0.597015
# Shipping_Mode       0.000000
# Shipping_Cost       0.497512
# Delivery_Status     0.000000
# Delivery_Days       0.000000
# dtype: float64

# %%
print(df.duplicated().sum())
# Out:
# 250

# %%
musk_ = df.duplicated(keep=False)
print(df[musk_].sort_values(by= "Order_ID"))
# Out:
#       Order_ID Customer_Region Product_Category Order_Date   Ship_Date  \
# 27     OR10027           South          Fashion  12/8/2024  12/11/2024
# 50195  OR10027           South          Fashion  12/8/2024  12/11/2024
# 444    OR10444         Central          Grocery  5/15/2023   5/15/2023
# 50028  OR10444         Central          Grocery  5/15/2023   5/15/2023
# 50234  OR10507            West          Fashion  7/18/2022   7/19/2022
# ...        ...             ...              ...        ...         ...
# 50014  OR59487            West          Fashion   8/5/2022    8/8/2022
# 49743  OR59743           South          Grocery  7/12/2024   7/17/2024
# 50168  OR59743           South          Grocery  7/12/2024   7/17/2024
# 50155  OR59997           North          Grocery   6/9/2022    6/9/2022
# 49997  OR59997           North          Grocery   6/9/2022    6/9/2022
#
#       Delivery_Date Shipping_Mode Shipping_Cost Delivery_Status  Delivery_Days
# 27       12/20/2024       Express          81.0       Delivered              9
# 50195    12/20/2024       Express          81.0       Delivered              9
# 444       5/17/2023      Standard          91.0       Delivered              2
# 50028     5/17/2023      Standard          91.0       Delivered              2
# 50234     7/21/2022      Standard          62.0       Delivered              2
# ...             ...           ...           ...             ...            ...
# 50014     8/13/2022       Express         161.0       Delivered              5
# 49743     7/27/2024      Standard          94.0       Delivered             10
# 50168     7/27/2024      Standard          94.0       Delivered             10
# 50155     6/11/2022       Express          83.0       Delivered              2
# 49997     6/11/2022       Express          83.0       Delivered              2
#
# [500 rows x 10 columns]

# %%
print(df["Product_Category"].unique())
print(df["Customer_Region"].unique())
print(df["Customer_Region"].str.lower().unique())
print(df["Delivery_Status"].unique())
# Out:
# <StringArray>
# ['Home', 'Grocery', 'Sports', 'Fashion', 'Beauty', 'Electronics']
# Length: 6, dtype: str
# <StringArray>
# [    'West',  'Central',     'East',    'South',    'North',     'east',
#    ' North',   'South ',    'SOUTH',    ' West',     'WEST', 'Central ',
#    'North ',  'CENTRAL',  'central',    'NORTH',    ' East',    'West ',
#     'East ', ' Central',     'west',    'south',     'EAST',   ' South',
#     'north']
# Length: 25, dtype: str
# <StringArray>
# [    'west',  'central',     'east',    'south',    'north',   ' north',
#    'south ',    ' west', 'central ',   'north ',    ' east',    'west ',
#     'east ', ' central',   ' south']
# Length: 15, dtype: str
# <StringArray>
# ['Delivered', 'Delayed', 'Returned']
# Length: 3, dtype: str

# %%
# check numeriks
print(df.dtypes) # date str, cost str
print(df.describe()) # negative Delivery_Days
print(df[df["Delivery_Days"] < 0])
# Out:
# Order_ID              str
# Customer_Region       str
# Product_Category      str
# Order_Date            str
# Ship_Date             str
# Delivery_Date         str
# Shipping_Mode         str
# Shipping_Cost         str
# Delivery_Status       str
# Delivery_Days       int64
# dtype: object
#        Delivery_Days
# count   50250.000000
# mean        5.982687
# std         2.587454
# min        -3.000000
# 25%         4.000000
# 50%         6.000000
# 75%         8.000000
# max        13.000000
#       Order_ID Customer_Region Product_Category  Order_Date   Ship_Date  \
# 82     OR10082         Central          Fashion    4/1/2024    4/2/2024
# 423    OR10423           South           Sports   7/16/2024   7/20/2024
# 1248   OR11248         Central           Beauty   5/21/2022   5/26/2022
# 1837   OR11837            West           Beauty   1/20/2025   1/22/2025
# 2048   OR12048            East          Fashion   12/4/2025   12/4/2025
# 2371   OR12371         Central      Electronics   3/12/2025   3/17/2025
# 3342   OR13342            East             Home  10/12/2024  10/17/2024
# 4218   OR14218           North             Home  10/23/2025  10/27/2025
# 5208   OR15208         Central      Electronics   2/18/2024   2/21/2024
# 12759     8/26/2022       Express         141.0       Delivered             -2
# 13175    11/20/2025       Express         174.0       Delivered             -2
# 14149     6/12/2022      Standard          58.0       Delivered             -2
# 14808      6/9/2022       Express         144.0       Delivered             -1
# 14890    11/15/2023      Standard          62.0       Delivered             -2
# 14937     9/27/2022      Same Day         310.0       Delivered             -2
# 16835      8/7/2022       Express         140.0       Delivered             -2
# 17233      3/1/2022      Standard          93.0       Delivered             -2
# 20812     1/25/2024      Standard          83.0       Delivered             -2
# 21877     9/26/2024       Express         195.0       Delivered             -2
# 23482      6/7/2023       Express          85.0       Delivered             -3
# 26110     8/20/2023      Same Day         218.0       Delivered             -3
# 26130    12/30/2025      Standard          78.0       Delivered             -1
# 26421      4/4/2024      Standard          56.0       Delivered             -1
# 27383    10/24/2022      Standard         129.0       Delivered             -3
# 28148     10/6/2022       Express         166.0       Delivered             -1
# 28944      5/4/2023      Standard         110.0       Delivered             -1
# 29730     8/30/2023      Standard         148.0       Delivered             -2
# 32289     8/16/2023      Standard          50.0       Delivered             -1
# 32338      7/5/2023       Express         133.0       Delivered             -2
# 32511      7/4/2025      Standard         130.0       Delivered             -1
# 33600     6/11/2023      Standard          82.0       Delivered             -1
# 35487     8/30/2025       Express         234.0       Delivered             -3
# 36472    12/18/2023       Express         129.0         Delayed             -1
# 36606     1/22/2022       Express         142.0       Delivered             -2
# 38624     6/29/2025      Standard          95.0         Delayed             -3
# 38821     10/7/2023       Express         122.0       Delivered             -1
# 42100     3/26/2022      Same Day         365.0         Delayed             -2
# 42563    10/11/2024       Express         211.0       Delivered             -2
# 43152     6/28/2022      Standard         147.0       Delivered             -3
# 43510     8/30/2022      Standard          64.0       Delivered             -2
# 44241     2/10/2022      Standard          82.0       Delivered             -2
# 45542      1/6/2022      Standard         141.0        Returned             -3
# 47861      2/9/2023       Express         198.0       Delivered             -2
# 49009     1/25/2023       Express         117.0       Delivered             -1
# 49077      2/9/2022       Express         241.0       Delivered             -3
# 49642     3/26/2024      Standard         118.0        Returned             -3

# %%
summary = {
    "rows": len(df),
    "colmens": len(df.columns),
    "worth flagging" : ["date - str instead date", "cost - str insted float"],
    "Missing values per affected column": df.isna().sum(),
    "Missing values in percentage" : df.isna().sum() / len(df) * 100,
    "Customer_Region values": df["Customer_Region"].nunique(),
    "wanted Customer_Region values": df["Customer_Region"].str.lower().nunique(),
    "unexpected minimum value": "Delivery_Days"
    
}
# result = pd.DataFrame(summary.values(), columns= summary.items())
print(summary)
# Out:
# {'rows': 50250, 'colmens': 10, 'worth flagging': ['date - str instead date', 'cost - str insted float'], 'Missing values per affected column': Order_ID              0
# Customer_Region       0
# Product_Category      0
# Order_Date            0
# Ship_Date             0
# Delivery_Date       300
# Shipping_Mode         0
# Shipping_Cost       250
# Delivery_Status       0
# Delivery_Days         0
# dtype: int64, 'Missing values in percentage': Order_ID            0.000000
# Customer_Region     0.000000
# Product_Category    0.000000
# Order_Date          0.000000
# Ship_Date           0.000000
# Delivery_Date       0.597015
# Shipping_Mode       0.000000
# Shipping_Cost       0.497512
# Delivery_Status     0.000000
# Delivery_Days       0.000000
# dtype: float64, 'Customer_Region values': 25, 'wanted Customer_Region values': 15, 'unexpected minimum value': 'Delivery_Days'}
